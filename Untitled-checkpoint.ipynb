# %%
import numpy as np

# %%
import imutils

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
import pytesseract

# %%
img=cv2.imread('image5.jpg')
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray,cv2.COLOR_BGR2RGB))

# %%
bfilter=cv2.bilateralFilter(gray,11,17,17)#nise reduction
edged=cv2.Canny(bfilter,30,200)#Edge detection
plt.imshow(cv2.cvtColor(edged,cv2.COLOR_BGR2RGB))

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %%
location
# Out:
# array([[[425, 737]],
#
#        [[667, 741]],
#
#        [[671, 813]],
#
#        [[431, 805]]], dtype=int32)

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %%
plt.axis('off')
plt.imshow(cropped_image)
plt.savefig('saved_figure.png', transparent=True,dpi=520)

# %%
from PIL import Image

# %%
from pytesseract import pytesseract

# %%
image_path = r"saved_figure.png"
img = Image.open(image_path)
path_to_tesseract = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
pytesseract.tesseract_cmd = path_to_tesseract
text = pytesseract.image_to_string(img)
print(text)
# Out:
# firP-co7ns

# %%
M = np.float32([[1,0,25],[0,1,25]])
img = cv2.warpAffine(img,M,(2,2),borderValue=(127,127,127))
custom_oem_psm_config = r'--oem 3 --psm 3 '
print(pytesseract.image_to_string(img,config=custom_oem_psm_config))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11476/2912512715.py in <module>
#       1 M = np.float32([[1,0,25],[0,1,25]])
# ----> 2 img = cv2.warpAffine(img,M,(2,2),borderValue=(127,127,127))
#       3 custom_oem_psm_config = r'--oem 3 --psm 3 '
#       4 print(pytesseract.image_to_string(img,config=custom_oem_psm_config))
#
# error: OpenCV(4.5.4) :-1: error: (-5:Bad argument) in function 'warpAffine'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
text
# Out:
# ''
